# %% [markdown]
# # Gradiente morfológico

# %%
ss



El sdc

# %%
meb_image = cv2.imread('images/meb.png', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(meb_image, cmap='gray', vmin=0, vmax=255)

# %%
mask = footprint_rectangle((3,3))

# %%
mgimage = morphological_gradient(meb_image, footprint=mask)

# %%
plt.imshow(mgimage, cmap='gray', vmin=0, vmax=255)

# %%
img_norma = sobel(meb_image)
rescaled_img = exposure.rescale_intensity(img_norma, in_range=(0, 0.6), out_range=(0, 255))
plt.imshow(rescaled_img, cmap='gray', vmin=0, vmax=255)

# %%
median = median(meb_image, footprint=mask)
dilated_image = dilation(median, footprint=mask)
eroded_image = erosion(median, footprint=mask)
subtracted_image = cv2.subtract(dilated_image, eroded_image)

# %% [markdown]
# ## Compare los resultados obtenidos (gradiente morfológico vs. norma del gradiente con Sobel).

# %%
plt.imshow(subtracted_image, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ## ¿Cómo es el resultado obtenido?
