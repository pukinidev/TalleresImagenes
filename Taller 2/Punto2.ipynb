# %% [markdown]
# # Ecualización del histograma

# %%
import cv2
import matplotlib.pyplot as plt

# %%
imagen_quito = cv2.imread('images/QUITO.png', cv2.IMREAD_GRAYSCALE)
imagen_baboon = cv2.imread('images/BABOON.png', cv2.IMREAD_GRAYSCALE)

# %%
def mostrar_histograma(imagen):
    hist = cv2.calcHist([imagen],[0],None,[256],[0,256])
    plt.plot(hist)
    plt.show()

# %%
hist_quito = mostrar_histograma(imagen_quito)

# %%
plt.imshow(imagen_quito, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ## Ecualización de la imagen QUITO

# %%
image_quito_ecu = cv2.equalizeHist(imagen_quito)

# %%
plt.imshow(image_quito_ecu, cmap='gray', vmin=0, vmax=255)

# %%
mostrar_histograma(image_quito_ecu)

# %% [markdown]
# ## Segunda equalización de la imagen QUITO

# %%
segundo_quito_ecu = cv2.equalizeHist(image_quito_ecu)

# %%
plt.imshow(segundo_quito_ecu, cmap='gray', vmin=0, vmax=255)

# %%
mostrar_histograma(segundo_quito_ecu)

# %% [markdown]
# ## Equalización de la imagen BABOON

# %% [markdown]
# ### Histograma Original

# %%
mostrar_histograma(imagen_baboon)

# %%
plt.imshow(imagen_baboon, cmap='gray', vmin=0, vmax=255)

# %%
imagen_baboon_ecu = cv2.equalizeHist(imagen_baboon)

# %%
plt.imshow(imagen_baboon_ecu, cmap='gray', vmin=0, vmax=255)

# %%
mostrar_histograma(imagen_baboon_ecu)

# %% [markdown]
# ## Segunda equalización de la imagen BABOON

# %%
segunda_baboon_ecu = cv2.equalizeHist(imagen_baboon_ecu)

# %%
plt.imshow(segunda_baboon_ecu, cmap='gray', vmin=0, vmax=255)

# %%
mostrar_histograma(segunda_baboon_ecu)
